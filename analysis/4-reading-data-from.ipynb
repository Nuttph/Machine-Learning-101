# %% [markdown]
# ## Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '[{"name": "Nuttaphon","age": 21},{"name": "Poparidt","age": 19}]'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#         name  age
# 0  Nuttaphon   21
# 1   Poparidt   19

# %%
df.to_json()
# Out:
# '{"name":{"0":"Nuttaphon","1":"Poparidt"},"age":{"0":21,"1":19}}'

# %%
df.to_json(orient="records")
# Out:
#   Cell In[24], line 1
#     df.to_json(orient="records","hello.json")
#                                             ^
# SyntaxError: positional argument follows keyword argument
